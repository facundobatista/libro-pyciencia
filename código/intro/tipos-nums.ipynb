# %% [markdown]
# # Tipos de datos: Números

# %% [markdown]
# ### Enteros, operaciones básicas

# %%
3 + 5
# Out:
# 8

# %%
2 - 8
# Out:
# -6

# %%
4 * -8
# Out:
# -32

# %%
32 / 5
# Out:
# 6.4

# %%
5 ** 2
# Out:
# 25

# %% [markdown]
# ### Extras división

# %%
32 // 5
# Out:
# 6

# %%
32 % 5
# Out:
# 2

# %%
divmod(32, 5)
# Out:
# (6, 2)

# %% [markdown]
# ### Enteros sin límite

# %%
2529 ** 15 * 1834
# Out:
# 2030634551567076694888541641414492972028354488232975466

# %% [markdown]
# ### Otras bases

# %%
0b1001010
# Out:
# 74

# %%
0x3f
# Out:
# 63

# %%
hex(63)
# Out:
# '0x3f'

# %%
bin(74)
# Out:
# '0b1001010'

# %% [markdown]
# ### Operando sobre bits

# %%
bin(0b1001 & 0b0001)
# Out:
# '0b1'

# %%
bin(0b1001 | 0b0001)
# Out:
# '0b1001'

# %%
bin(0b1001 ^ 0b0001)
# Out:
# '0b1000'

# %%
bin(0b1100 << 2)
# Out:
# '0b110000'

# %%
bin(0b1100 >> 2)
# Out:
# '0b11'

# %% [markdown]
# ### Punto flotante binario

# %%
2.35 * 28
# Out:
# 65.8

# %%
15 + 2.3
# Out:
# 17.3

# %%
95 / 17
# Out:
# 5.588235294117647

# %%
2.3 ** 15
# Out:
# 266635.23546439095

# %% [markdown]
# ### Punto flotante decimal

# %%
from decimal import Decimal

Decimal(23) * 53
# Out:
# Decimal('1219')

# %%
Decimal(15.4) + 87
# Out:
# Decimal('102.4000000000000003552713679')

# %%
Decimal('15.4') + 87
# Out:
# Decimal('102.4')

# %% [markdown]
# ### Fracciones

# %%
from fractions import Fraction

Fraction(1, 3) * 6
# Out:
# Fraction(2, 1)

# %%
Fraction(27, 5) ** 2
# Out:
# Fraction(729, 25)

# %%
Fraction(2, 3) + Fraction(6, 9)
# Out:
# Fraction(4, 3)

# %% [markdown]
# ### Números complejos

# %%
3j
# Out:
# 3j

# %%
3j + 2
# Out:
# (2+3j)

# %%
(3j + 2) * (7 + 2.5j)
# Out:
# (6.5+26j)

# %%
1j ** 2
# Out:
# (-1+0j)

# %%
import math

x = 1.5
math.cos(x) + 1j * math.sin(x) == math.e ** (x * 1j)
# Out:
# True

# %% [markdown]
# ### Constructores

# %%
int()
# Out:
# 0

# %%
int(9.2)
# Out:
# 9

# %%
float(-7)
# Out:
# -7.0

# %% [markdown]
# ### Copyright 2020-2021 Facundo Batista y Manuel Carlevaro
#
# Licencia CC BY-NC-SA 4.0
#
# Para más info visitar: https://github.com/facundobatista/libro-pyciencia/
