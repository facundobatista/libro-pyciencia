# %% [markdown]
# # Tipos de datos: Listas

# %% [markdown]
# ### Definiendo, operando, accediendo

# %%
lista = [1, "a", 5.6, "foo"]
lista
# Out:
# [1, 'a', 5.6, 'foo']

# %%
len(lista)
# Out:
# 4

# %%
lista[1]
# Out:
# 'a'

# %%
lista[2:]
# Out:
# [5.6, 'foo']

# %%
lista * 2
# Out:
# [1, 'a', 5.6, 'foo', 1, 'a', 5.6, 'foo']

# %%
lista + [1, 2]
# Out:
# [1, 'a', 5.6, 'foo', 1, 2]

# %% [markdown]
# ### Agregando y extendiendo

# %%
lista = [1, 2, 3]
lista
# Out:
# [1, 2, 3]

# %%
lista.append(4)
lista
# Out:
# [1, 2, 3, 4]

# %%
otra = [5, 6]
lista.extend(otra)
lista
# Out:
# [1, 2, 3, 4, 5, 6]

# %% [markdown]
# ### Reemplazando

# %%
lista
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
lista[1] = 99
lista
# Out:
# [1, 99, 3, 4, 5, 6]

# %%
lista[2:] = [0, 0]
lista
# Out:
# [1, 99, 0, 0]

# %% [markdown]
# ### Borrando

# %%
lista
# Out:
# [1, 99, 0, 0]

# %%
lista.remove(99)
lista
# Out:
# [1, 0, 0]

# %%
del lista[1]
lista
# Out:
# [1, 0]

# %% [markdown]
# ### Construyendo

# %%
list("abcd")
# Out:
# ['a', 'b', 'c', 'd']

# %% [markdown]
# ### Copyright 2020-2021 Facundo Batista y Manuel Carlevaro
#
# Licencia CC BY-NC-SA 4.0
#
# Para más info visitar: https://github.com/facundobatista/libro-pyciencia/
