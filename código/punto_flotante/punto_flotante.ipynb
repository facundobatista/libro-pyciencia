# %%
import numpy as np

np.single
# Out:
# numpy.float32

# %%
np.double
# Out:
# numpy.float64

# %%
1 / 10
# Out:
# 0.1

# %%
from decimal import Decimal

Decimal(0.1)
# Out:
# Decimal('0.1000000000000000055511151231257827021181583404541015625')

# %%
Decimal(0.1)
# Out:
# Decimal('0.1000000000000000055511151231257827021181583404541015625')

# %%
Decimal(0.10000000000000001)
# Out:
# Decimal('0.1000000000000000055511151231257827021181583404541015625')

# %%
x = 9
for _ in range(10):
    print(x)
    x /= 10
# Out:
# 9
# 0.9
# 0.09
# 0.009
# 0.0009
# 8.999999999999999e-05
# 8.999999999999999e-06
# 8.999999999999999e-07
# 8.999999999999999e-08
# 8.999999999999998e-09

# %%
x = 9
for _ in range(10):
    print(Decimal(x))
    x /= 10
# Out:
# 9
# 0.90000000000000002220446049250313080847263336181640625
# 0.0899999999999999966693309261245303787291049957275390625
# 0.00899999999999999931998839741709161899052560329437255859375
# 0.00089999999999999997536692664112933925935067236423492431640625
# 0.00008999999999999999211568180168541175589780323207378387451171875
# 0.00000899999999999999853394182236510090433512232266366481781005859375
# 8.99999999999999853394182236510090433512232266366481781005859375E-7
# 8.99999999999999853394182236510090433512232266366481781005859375E-8
# 8.999999999999997872197332322678764437995369007694534957408905029296875E-9

# %%
import sys
sys.float_info.epsilon
# Out:
# 2.220446049250313e-16

# %%
0.3 + 0.3 + 0.3 + 0.3 + 0.3 + 0.3 + 0.3 + 0.3 + 0.3 + 0.3
# Out:
# 2.9999999999999996

# %%
0.3 + 0.3 + 0.3 + 0.3 + 0.3 + 0.3 + 0.3 + 0.3 + 0.3 + 0.3 == 0.3 * 10
# Out:
# False

# %%
5.4 + 0.3 == 5.7
# Out:
# True

# %%
5.4 + 0.4 == 5.8
# Out:
# False

# %%
epsilon = 0.00000000001
a = 5.4 + 0.3
b = 5.7
abs(a - b) < epsilon
# Out:
# True

# %%
a = 5.4 + 0.4
b = 5.8
abs(a - b) < epsilon
# Out:
# True

# %%
a = 168163.005
b = 168163.004
c = .0000000000123
a - b
# Out:
# 0.0010000000183936208

# %%
a - c - b  # restar "c" se perdió totalmente!!
# Out:
# 0.0010000000183936208

# %%
a - b - c  # acá sí influyó "c"
# Out:
# 0.0010000000060936209

# %% [markdown]
# ### Copyright 2020-2025 Facundo Batista y Manuel Carlevaro
#
# Licencia CC BY-NC-SA 4.0
#
# Para más info visitar: https://github.com/facundobatista/libro-pyciencia/
