# %% [markdown]
# # Tipos de datos: Pensando como un pythonista

# %% [markdown]
# ### Ejemplo sencillo

# %%
a = [1, 2]
b = [1, 2]

# %%
a == b
# Out:
# True

# %%
a is b
# Out:
# False

# %%
a.append(3)
a
# Out:
# [1, 2, 3]

# %%
b
# Out:
# [1, 2]

# %%
c = b
c
# Out:
# [1, 2]

# %%
c == b
# Out:
# True

# %%
c is b
# Out:
# True

# %%
c.append(5)
c
# Out:
# [1, 2, 5]

# %%
b
# Out:
# [1, 2, 5]

# %% [markdown]
# ### Otro ejemplo

# %%
a = [1, 2]
b = [3, 4]
c = [a, b]
c
# Out:
# [[1, 2], [3, 4]]

# %%
a.append(5)
a
# Out:
# [1, 2, 5]

# %%
c
# Out:
# [[1, 2, 5], [3, 4]]

# %%
b = "foo"
b
# Out:
# 'foo'

# %%
c
# Out:
# [[1, 2, 5], [3, 4]]

# %%
d = c[1]
d
# Out:
# [3, 4]

# %%
d.append(7)
d
# Out:
# [3, 4, 7]

# %%
c
# Out:
# [[1, 2, 5], [3, 4, 7]]

# %% [markdown]
# ### Copyright 2020-2025 Facundo Batista y Manuel Carlevaro
#
# Licencia CC BY-NC-SA 4.0
#
# Para más info visitar: https://github.com/facundobatista/libro-pyciencia/
