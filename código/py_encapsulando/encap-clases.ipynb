# %% [markdown]
# # Encapsulando código: Clases

# %% [markdown]
# ### Ejemplo básico

# %%
class Foo:
    a = 3
    def f():
        print(8)
        
Foo
# Out:
# __main__.Foo

# %%
Foo.a
# Out:
# 3

# %%
Foo.f
# Out:
# <function __main__.Foo.f()>

# %%
Foo.f()
# Out:
# 8

# %% [markdown]
# ### Una clase con más sentido

# %%
import math

class TriánguloRectángulo:
    def __init__(self, cateto1, cateto2):
        self.cateto1 = cateto1
        self.cateto2 = cateto2
    def hipotenusa(self):
        return math.sqrt(self.cateto1 ** 2 + self.cateto2 ** 2)

# %%
t1 = TriánguloRectángulo(4, 5)
t1

# %%
t2 = TriánguloRectángulo(10, 1)
t2

# %%
t1.cateto1
# Out:
# 4

# %%
t2.cateto1
# Out:
# 10

# %%
t1.hipotenusa()
# Out:
# 6.4031242374328485

# %%
t2.hipotenusa()
# Out:
# 10.04987562112089

# %% [markdown]
# ### Herencia, para definir excepciones

# %%
class NoNegativos(ValueError):
    """Usada al encontrar números negativos, que no se puede."""

# %% [markdown]
# ### Copyright 2020-2025 Facundo Batista y Manuel Carlevaro
#
# Licencia CC BY-NC-SA 4.0
#
# Para más info visitar: https://github.com/facundobatista/libro-pyciencia/
