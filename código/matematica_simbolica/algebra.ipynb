# %%
import sympy as sym
x, y, z = sym.symbols('x y z')

# %%
sym.simplify( (x ** 3 - 2 * x ** 2 - 13 * x - 10) / (x ** 2 - 4 * x - 5))
# Out:
# x + 2

# %%
sym.simplify(2 * sym.cos(x)**2 + 2 * sym.sin(x)**2)
# Out:
# 2

# %%
sym.simplify(sym.gamma(x)/sym.gamma(x - 1))
# Out:
# x - 1

# %%
sym.simplify(x ** 2 + 4 * x + 4)
# Out:
# x**2 + 4*x + 4

# %%
sym.expand((x - 2) * (x + 3) * (x - 1))
# Out:
# x**3 - 7*x + 6

# %%
sym.expand((x + 1) ** 4)
# Out:
# x**4 + 4*x**3 + 6*x**2 + 4*x + 1

# %%
sym.expand((x + 1)*(x - 2) - (x - 1)*x)
# Out:
# -2

# %%
sym.factor(x ** 3 + x ** 2 - x - 1)
# Out:
# (x - 1)*(x + 1)**2

# %%
sym.factor(x ** 2 * z + 4 * x * y * z + 4 * y ** 2 * z)
# Out:
# z*(x + 2*y)**2

# %%
sym.factor_list(x ** 2 * z + 4 * x * y * z + 4 * y ** 2 * z)
# Out:
# (1, [(z, 1), (x + 2*y, 2)])

# %%
sym.expand((sym.cos(x) + sym.sin(x)) ** 2)
# Out:
# sin(x)**2 + 2*sin(x)*cos(x) + cos(x)**2

# %%
sym.factor(sym.cos(x) ** 2 + sym.sin(x) ** 2 - 2 * sym.sin(x) * sym.cos(x))
# Out:
# (-sin(x) + cos(x))**2

# %%
expresión = x ** 4 + 3 * (x * z) ** 3 + x ** 2 + x * y - z * x
sym.collect(expresión , x)
# Out:
# x**4 + 3*x**3*z**3 + x**2 + x*(y - z)

# %%
expresión.coeff(x, 3)
# Out:
# 3*z**3

# %%
sym.cancel((x ** 2 + 4 * x + 4) / (x ** 2 + 2 * x))
# Out:
# (x + 2)/x

# %%
expresión = 1 / x + (5 * x / 4 - 4)/(x - 2)
expresión
# Out:
# (5*x/4 - 4)/(x - 2) + 1/x

# %%
sym.cancel(expresión)
# Out:
# (5*x**2 - 12*x - 8)/(4*x**2 - 8*x)

# %%
e_racional = (x ** 2 + 3 * x + 1) / (x + 1) ** 3
e_racional
# Out:
# (x**2 + 3*x + 1)/(x + 1)**3

# %%
sym.apart(e_racional)
# Out:
# 1/(x + 1) + (x + 1)**(-2) - 1/(x + 1)**3

# %%
sym.trigsimp(sym.sin(x) ** 2 + sym.cos(x) ** 2)
# Out:
# 1

# %%
sym.trigsimp(sym.sin(x) / sym.tan(x))
# Out:
# cos(x)

# %%
sym.trigsimp(sym.sinh(x) ** 2 + sym.cosh(x) **2)
# Out:
# cosh(2*x)

# %%
sym.expand_trig(sym.sin(x) + sym.sin(3 * x))
# Out:
# -4*sin(x)**3 + 4*sin(x)

# %%
x, y = sym.symbols('x y', positive=True)
a, b = sym.symbols('a b', real=True)
m, n, l = sym.symbols('m n l')

# %%
sym.powsimp(x ** a * x ** b)
# Out:
# x**(a + b)

# %%
sym.powsimp(x ** a * y ** a)
# Out:
# (x*y)**a

# %%
sym.powsimp(m ** l * n ** l)
# Out:
# m**l*n**l

# %%
sym.powsimp(m ** l * n ** l, force=True)
# Out:
# (m*n)**l

# %%
sym.expand_power_exp(x ** (a + b))
# Out:
# x**a*x**b

# %%
sym.expand_power_base((x * y) ** a)
# Out:
# x**a*y**a

# %%
sym.expand_power_base((m * n) ** l)
# Out:
# (m*n)**l

# %%
sym.expand_power_base((m * n) ** l, force=True)
# Out:
# m**l*n**l

# %%
sym.powdenest((x ** a) ** b)
# Out:
# x**(a*b)

# %%
sym.powdenest((m ** a) ** b)
# Out:
# (m**a)**b

# %%
sym.powdenest((m ** a) ** b, force=True)
# Out:
# m**(a*b)

# %%
x, y = sym.symbols('x y', positive=True)
n = sym.symbols('n', real=True)
p, q = sym.symbols('p q')

# %%
sym.expand_log(sym.log(x * y))
# Out:
# log(x) + log(y)

# %%
sym.expand_log(sym.log(x / y))
# Out:
# log(x) - log(y)

# %%
sym.expand_log(sym.log(x ** 3))
# Out:
# 3*log(x)

# %%
sym.expand_log(sym.log(x ** n))
# Out:
# n*log(x)

# %%
sym.expand_log(sym.log(p * q))
# Out:
# log(p*q)

# %%
sym.expand_log(sym.log(p * q), force=True)
# Out:
# log(p) + log(q)

# %%
sym.logcombine(sym.log(x) + sym.log(y))
# Out:
# log(x*y)

# %%
sym.logcombine(n * sym.log(x))
# Out:
# log(x**n)

# %%
sym.logcombine(n * sym.log(p))
# Out:
# n*log(p)

# %%
sym.logcombine(n * sym.log(p), force=True)
# Out:
# log(p**n)

# %%
sym.tan(x).rewrite(sym.sin)
# Out:
# 2*sin(x)**2/sin(2*x)

# %%
sym.factorial(x).rewrite(sym.gamma)
# Out:
# gamma(x + 1)

# %%
n, k = sym.symbols('n k', integer=True)
sym.combsimp(sym.factorial(n + 1) / sym.factorial(n - 1))
# Out:
# n*(n + 1)

# %%
sym.combsimp(sym.binomial(n + 2, k + 2) / sym.binomial(n, k))
# Out:
# (n + 1)*(n + 2)/((k + 1)*(k + 2))

# %%
sym.gammasimp(sym.gamma(2 + x) * sym.gamma(1 - x))
# Out:
# pi*x*(x + 1)/sin(pi*x)

# %%
sym.expand_func(sym.gamma(x + 4))
# Out:
# x*(x + 1)*(x + 2)*(x + 3)*gamma(x)

# %% [markdown]
# ### Copyright 2020-2025 Facundo Batista y Manuel Carlevaro
#
# Licencia CC BY-NC-SA 4.0
#
# Para más info visitar: https://github.com/facundobatista/libro-pyciencia/
